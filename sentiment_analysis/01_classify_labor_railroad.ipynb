# %% [markdown]
# # Stage 1: Classify Articles as Labor, Railroad, or Both
#
# Query the SQLite database (~83M articles) and classify articles into three categories using weighted keyword matching with exclusion patterns.
#
# **Output**: `data/classified_articles/{labor_only,railroad_only,both}.json` (~100K articles each)

# %%
import sqlite3
import json
import re
import hashlib
import logging
import os
import random
from pathlib import Path
from tqdm import tqdm

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler("data/classification_log.log")
    ]
)
log = logging.getLogger(__name__)

# Paths (relative to sentiment_analysis/)
DB_PATH = os.path.join("..", "data", "newspapers.db")
OUTPUT_DIR = Path("data/classified_articles")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Database path: {DB_PATH}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Database path: ..\data\newspapers.db
# Output directory: data\classified_articles

# %% [markdown]
# ## Keyword Definitions
#
# Weighted scoring system:
# - **High-weight (3 pts)**: Multi-word phrases that are unambiguously labor/railroad
# - **Medium-weight (2 pts)**: Specific terms with low false-positive rates
# - **Low-weight (1 pt)**: Ambiguous single terms ("strike", "union", "train")
#
# Articles must score **>=5** in a category to be classified. This prevents a single ambiguous word from triggering a match.

# %%
# --- Weighted keyword dictionaries ---

LABOR_KEYWORDS = {
    # High-weight (3): unambiguous multi-word phrases
    'labor union': 3, 'trade union': 3, 'labor strike': 3, 'labor riot': 3,
    'collective bargaining': 3, 'labor movement': 3, 'strikebreaker': 3,
    'scab labor': 3, 'working men': 3, 'workingmen': 3,
    'knights of labor': 3, 'eight hour': 3,
    # Medium-weight (2): specific terms
    'striker': 2, 'strikers': 2, 'picket': 2, 'lockout': 2,
    'boycott': 2, 'walkout': 2, 'arbitration': 2, 'picketing': 2,
    # Low-weight (1): ambiguous terms
    'strike': 1, 'strikes': 1, 'wage': 1, 'wages': 1,
    'workers': 1, 'laborers': 1,
}

RAILROAD_KEYWORDS = {
    # High-weight (3): unambiguous multi-word phrases
    'railroad company': 3, 'railroad strike': 3, 'railroad workers': 3,
    'railway company': 3, 'union pacific': 3, 'central pacific': 3,
    'northern pacific': 3, 'pennsylvania railroad': 3,
    'baltimore and ohio': 3, 'railroad line': 3,
    # Medium-weight (2): specific terms
    'locomotive': 2, 'locomotives': 2, 'brakeman': 2,
    'freight car': 2, 'passenger car': 2, 'rail road': 2,
    # Low-weight (1): ambiguous terms
    'railroad': 1, 'railway': 1, 'train': 1, 'trains': 1,
}

# Exclusion patterns: if ANY match, disqualify the article
EXCLUSION_PATTERNS = [
    # Civil War "Union" (dominant in 1869-1880s newspapers)
    re.compile(r'\b(union army|union forces|union troops|union soldier|union soldiers'
               r'|union victory|union general|federal union|union cause|union side)\b', re.IGNORECASE),
    # Strike false positives
    re.compile(r'\b(struck gold|strike gold|strike oil|struck oil'
               r'|lightning strike|strike a match|struck a match|strike a blow|struck a blow'
               r'|struck the ball|strike the ball|clock struck)\b', re.IGNORECASE),
    # Railroad false positives
    re.compile(r'\bunderground railroad\b', re.IGNORECASE),
]

# Pre-compile keyword regexes for speed
LABOR_PATTERNS = {kw: (re.compile(r'\b' + re.escape(kw) + r'\b', re.IGNORECASE), weight)
                  for kw, weight in LABOR_KEYWORDS.items()}
RAILROAD_PATTERNS = {kw: (re.compile(r'\b' + re.escape(kw) + r'\b', re.IGNORECASE), weight)
                     for kw, weight in RAILROAD_KEYWORDS.items()}

SCORE_THRESHOLD = 4

print(f"Labor keywords: {len(LABOR_KEYWORDS)} ({sum(LABOR_KEYWORDS.values())} max score)")
print(f"Railroad keywords: {len(RAILROAD_KEYWORDS)} ({sum(RAILROAD_KEYWORDS.values())} max score)")
print(f"Classification threshold: >= {SCORE_THRESHOLD} points")
# Out:
# Labor keywords: 26 (58 max score)
# Railroad keywords: 20 (46 max score)
# Classification threshold: >= 4 points

# %%
def is_excluded(text: str) -> bool:
    """Check if article matches any exclusion pattern."""
    for pattern in EXCLUSION_PATTERNS:
        if pattern.search(text):
            return True
    return False


def score_text(text: str, patterns: dict) -> tuple[int, int]:
    """Calculate weighted keyword score for text. Returns (score, match_count)."""
    score = 0
    match_count = 0
    for kw, (regex, weight) in patterns.items():
        if regex.search(text):
            score += weight
            match_count += 1
    return score, match_count


def classify_article(text: str) -> dict | None:
    """
    Classify a single article using weighted keyword scoring.
    
    Returns dict with category and scores, or None if not classified.
    """
    if is_excluded(text):
        return None

    labor_score, labor_matches = score_text(text, LABOR_PATTERNS)
    railroad_score, railroad_matches = score_text(text, RAILROAD_PATTERNS)

    if labor_score >= SCORE_THRESHOLD-1 and railroad_score >= SCORE_THRESHOLD-1:
        return {'category': 'both', 'labor_score': labor_score, 'railroad_score': railroad_score,
                'labor_matches': labor_matches, 'railroad_matches': railroad_matches}
    elif labor_score >= SCORE_THRESHOLD:
        return {'category': 'labor', 'labor_score': labor_score, 'railroad_score': railroad_score,
                'labor_matches': labor_matches, 'railroad_matches': railroad_matches}
    elif railroad_score >= SCORE_THRESHOLD:
        return {'category': 'railroad', 'labor_score': labor_score, 'railroad_score': railroad_score,
                'labor_matches': labor_matches, 'railroad_matches': railroad_matches}
    return None


def make_article_id(lccn: str, issn: str, year: int, text: str) -> str:
    """Generate a deterministic article ID from its contents."""
    raw = f"{lccn}|{issn}|{year}|{text[:500]}"
    return hashlib.sha256(raw.encode('utf-8', errors='replace')).hexdigest()[:16]


# Quick sanity test
test_cases = [
    ("The labor union called a strike against the railroad company", "both"),
    ("The strikers walked out and began picketing the factory", "labor"),
    ("The Union army marched south to strike a blow", None),  # Excluded
    ("The railroad company built a new locomotive depot", "railroad"),
    ("The weather was fine today", None),  # No match
]

for text, expected in test_cases:
    result = classify_article(text)
    actual = result['category'] if result else None
    status = 'PASS' if actual == expected else 'FAIL'
    print(f"  [{status}] '{text[:60]}...' -> {actual} (expected {expected})")
    print(result['labor_score'] if result else 'N/A', result['railroad_score'] if result else 'N/A')
# Out:
#   [PASS] 'The labor union called a strike against the railroad company...' -> both (expected both)
# 4 4
#   [PASS] 'The strikers walked out and began picketing the factory...' -> labor (expected labor)
# 4 0
#   [PASS] 'The Union army marched south to strike a blow...' -> None (expected None)
# N/A N/A
#   [PASS] 'The railroad company built a new locomotive depot...' -> railroad (expected railroad)
# 0 6
#   [PASS] 'The weather was fine today...' -> None (expected None)
# N/A N/A

# %% [markdown]
# ## SQL Pre-filtering
#
# Use SQL `LIKE` queries to pull candidate articles from the database. This is much faster than scanning all 44M articles with Python regex.
#
# Query broadly (using high/medium weight terms), then apply the full weighted classifier in Python.

# %%
# Build SQL LIKE clauses from high + medium weight keywords only
# (low-weight terms alone can't reach the threshold of 5)

def build_like_clause(keywords: dict, min_weight: int = 2) -> str:
    """Build SQL OR clause from keywords at or above min_weight."""
    terms = [kw for kw, weight in keywords.items() if weight >= min_weight]
    clauses = [f"text LIKE '%{term}%'" for term in terms]
    return " OR ".join(clauses)

labor_like = build_like_clause(LABOR_KEYWORDS, min_weight=2)
railroad_like = build_like_clause(RAILROAD_KEYWORDS, min_weight=2)

# Three queries: one for each potential category
# We over-sample since post-filtering will discard some
QUERIES = {
    'labor_candidates': f"""
        SELECT lccn, issn, year, text
        FROM articles
        WHERE ({labor_like})
    """,
    'railroad_candidates': f"""
        SELECT lccn, issn, year, text
        FROM articles
        WHERE ({railroad_like})
    """,
}

print("Labor SQL terms:", len([k for k, w in LABOR_KEYWORDS.items() if w >= 2]))
print("Railroad SQL terms:", len([k for k, w in RAILROAD_KEYWORDS.items() if w >= 2]))
# Out:
# Labor SQL terms: 20
# Railroad SQL terms: 16

# %%
# Connect and run queries
con = sqlite3.connect(DB_PATH)
con.row_factory = sqlite3.Row
cur = con.cursor()

# Check DB is accessible
cur.execute("SELECT COUNT(*) FROM articles")
total_articles = cur.fetchone()[0]
print(f"Total articles in database: {total_articles:,}")
# Out:
# Total articles in database: 44,269,986

# %%
# Pull candidates from both queries and classify with weighted scoring.
# We use a combined approach: query broadly, then classify precisely.

# To avoid duplicate processing, we'll query both sets and deduplicate
# by building a single pass through both candidate sets.

classified = {'labor': [], 'railroad': [], 'both': []}
seen_ids = set()
excluded_count = 0
below_threshold_count = 0

TARGET_PER_CATEGORY = 100_000

def all_categories_full() -> bool:
    return all(len(v) >= TARGET_PER_CATEGORY for v in classified.values())

for query_name, query in QUERIES.items():
    if all_categories_full():
        break

    log.info(f"Running query: {query_name}")
    cur.execute(query)

    batch_size = 10_000
    while True:
        rows = cur.fetchmany(batch_size)
        if not rows:
            break

        for row in rows:
            lccn, issn, year, text = row['lccn'], row['issn'], row['year'], row['text']

            article_id = make_article_id(lccn, issn or '', year, text)
            if article_id in seen_ids:
                continue
            seen_ids.add(article_id)

            result = classify_article(text)
            if result is None:
                if is_excluded(text):
                    excluded_count += 1
                else:
                    below_threshold_count += 1
                continue

            category = result['category']
            if len(classified[category]) >= TARGET_PER_CATEGORY:
                continue

            classified[category].append({
                'article_id': article_id,
                'lccn': lccn,
                'issn': issn or '',
                'year': year,
                'text': text,
                'category': category,
                'labor_score': result['labor_score'],
                'railroad_score': result['railroad_score'],
                'labor_matches': result['labor_matches'],
                'railroad_matches': result['railroad_matches'],
            })

        # Progress update
        counts = {k: len(v) for k, v in classified.items()}
        log.info(f"  Progress: {counts} | Excluded: {excluded_count} | Below threshold: {below_threshold_count}")

        if all_categories_full():
            break

con.close()

print(f"\nFinal counts:")
for cat, articles in classified.items():
    print(f"  {cat}: {len(articles):,}")
print(f"  Excluded (Civil War/false positives): {excluded_count:,}")
print(f"  Below threshold: {below_threshold_count:,}")
# Out:
# 2026-02-15 11:49:54,180 [INFO] Running query: labor_candidates
# 2026-02-15 11:53:07,171 [INFO]   Progress: {'labor': 1741, 'railroad': 197, 'both': 242} | Excluded: 63 | Below threshold: 7755
# 2026-02-15 11:56:30,364 [INFO]   Progress: {'labor': 3215, 'railroad': 359, 'both': 456} | Excluded: 104 | Below threshold: 15864
# 2026-02-15 11:59:48,278 [INFO]   Progress: {'labor': 4696, 'railroad': 557, 'both': 615} | Excluded: 156 | Below threshold: 23974
# 2026-02-15 12:03:11,420 [INFO]   Progress: {'labor': 6075, 'railroad': 803, 'both': 846} | Excluded: 201 | Below threshold: 32073
# 2026-02-15 12:07:02,871 [INFO]   Progress: {'labor': 7496, 'railroad': 1073, 'both': 1211} | Excluded: 237 | Below threshold: 39981
# 2026-02-15 12:11:29,337 [INFO]   Progress: {'labor': 8682, 'railroad': 1315, 'both': 1463} | Excluded: 277 | Below threshold: 48261
# 2026-02-15 12:16:29,278 [INFO]   Progress: {'labor': 9793, 'railroad': 1560, 'both': 1817} | Excluded: 336 | Below threshold: 56456
# 2026-02-15 12:19:26,050 [INFO]   Progress: {'labor': 11255, 'railroad': 1821, 'both': 3010} | Excluded: 384 | Below threshold: 63487
# 2026-02-15 12:22:36,335 [INFO]   Progress: {'labor': 12714, 'railroad': 1964, 'both': 3503} | Excluded: 413 | Below threshold: 71358
# 2026-02-15 12:25:47,124 [INFO]   Progress: {'labor': 14089, 'railroad': 2097, 'both': 3742} | Excluded: 486 | Below threshold: 79532
# 2026-02-15 12:29:43,890 [INFO]   Progress: {'labor': 15345, 'railroad': 2312, 'both': 3954} | Excluded: 588 | Below threshold: 87742
# 2026-02-15 12:33:17,384 [INFO]   Progress: {'labor': 16429, 'railroad': 2567, 'both': 4172} | Excluded: 672 | Below threshold: 96098
# 2026-02-15 12:36:34,926 [INFO]   Progress: {'labor': 17999, 'railroad': 2828, 'both': 4484} | Excluded: 726 | Below threshold: 103899
# 2026-02-15 12:39:45,454 [INFO]   Progress: {'labor': 19809, 'railroad': 3079, 'both': 4884} | Excluded: 772 | Below threshold: 111392
# 2026-02-15 12:42:44,477 [INFO]   Progress: {'labor': 21626, 'railroad': 3281, 'both': 5325} | Excluded: 834 | Below threshold: 118855
# 2026-02-15 12:45:52,446 [INFO]   Progress: {'labor': 23436, 'railroad': 3483, 'both': 5604} | Excluded: 931 | Below threshold: 126460
# 2026-02-15 12:48:54,079 [INFO]   Progress: {'labor': 25238, 'railroad': 3679, 'both': 5929} | Excluded: 1010 | Below threshold: 134047
# 2026-02-15 12:51:12,172 [INFO]   Progress: {'labor': 26913, 'railroad': 3902, 'both': 6490} | Excluded: 1089 | Below threshold: 141508
# 2026-02-15 12:53:33,119 [INFO]   Progress: {'labor': 28926, 'railroad': 4087, 'both': 7060} | Excluded: 1177 | Below threshold: 148650
# 2026-02-15 12:55:12,367 [INFO]   Progress: {'labor': 31846, 'railroad': 4214, 'both': 7710} | Excluded: 1244 | Below threshold: 154885
# 2026-02-15 12:56:51,918 [INFO]   Progress: {'labor': 34780, 'railroad': 4357, 'both': 8357} | Excluded: 1320 | Below threshold: 161081
# 2026-02-15 12:58:31,509 [INFO]   Progress: {'labor': 37749, 'railroad': 4484, 'both': 8995} | Excluded: 1386 | Below threshold: 167278
# 2026-02-15 13:00:10,377 [INFO]   Progress: {'labor': 40667, 'railroad': 4590, 'both': 9661} | Excluded: 1466 | Below threshold: 173503
# 2026-02-15 13:01:48,535 [INFO]   Progress: {'labor': 43573, 'railroad': 4722, 'both': 10366} | Excluded: 1537 | Below threshold: 179687
# 2026-02-15 13:03:43,013 [INFO]   Progress: {'labor': 46183, 'railroad': 4880, 'both': 10854} | Excluded: 1630 | Below threshold: 186337
# 2026-02-15 13:05:37,634 [INFO]   Progress: {'labor': 48503, 'railroad': 5033, 'both': 11267} | Excluded: 1711 | Below threshold: 193367
# 2026-02-15 13:07:40,240 [INFO]   Progress: {'labor': 50867, 'railroad': 5197, 'both': 11733} | Excluded: 1794 | Below threshold: 200286
# 2026-02-15 13:09:42,826 [INFO]   Progress: {'labor': 53297, 'railroad': 5373, 'both': 12198} | Excluded: 1885 | Below threshold: 207113
# 2026-02-15 13:11:56,079 [INFO]   Progress: {'labor': 55663, 'railroad': 5549, 'both': 12839} | Excluded: 1967 | Below threshold: 213848
# 2026-02-15 13:14:10,509 [INFO]   Progress: {'labor': 58066, 'railroad': 5726, 'both': 13516} | Excluded: 2042 | Below threshold: 220515
# 2026-02-15 13:16:22,473 [INFO]   Progress: {'labor': 60416, 'railroad': 5898, 'both': 14138} | Excluded: 2140 | Below threshold: 227263
# 2026-02-15 13:18:44,532 [INFO]   Progress: {'labor': 62659, 'railroad': 6107, 'both': 14644} | Excluded: 2225 | Below threshold: 234217
# 2026-02-15 13:21:20,503 [INFO]   Progress: {'labor': 64582, 'railroad': 6310, 'both': 14959} | Excluded: 2305 | Below threshold: 241682
# 2026-02-15 13:23:48,612 [INFO]   Progress: {'labor': 66509, 'railroad': 6527, 'both': 15279} | Excluded: 2372 | Below threshold: 249145
# 2026-02-15 13:25:59,472 [INFO]   Progress: {'labor': 68546, 'railroad': 6700, 'both': 15812} | Excluded: 2414 | Below threshold: 256357
# 2026-02-15 13:28:05,368 [INFO]   Progress: {'labor': 70636, 'railroad': 6841, 'both': 16327} | Excluded: 2475 | Below threshold: 263548
# 2026-02-15 13:30:13,774 [INFO]   Progress: {'labor': 72711, 'railroad': 7018, 'both': 16866} | Excluded: 2533 | Below threshold: 270699
# 2026-02-15 13:31:31,790 [INFO]   Progress: {'labor': 73987, 'railroad': 7115, 'both': 17188} | Excluded: 2567 | Below threshold: 275071
# 2026-02-15 13:31:31,797 [INFO] Running query: railroad_candidates
# 2026-02-15 13:33:08,839 [INFO]   Progress: {'labor': 73987, 'railroad': 14060, 'both': 17193} | Excluded: 2602 | Below threshold: 277935
# 2026-02-15 13:34:44,503 [INFO]   Progress: {'labor': 73987, 'railroad': 21047, 'both': 17197} | Excluded: 2629 | Below threshold: 280781
# 2026-02-15 13:36:19,706 [INFO]   Progress: {'labor': 73987, 'railroad': 28006, 'both': 17205} | Excluded: 2665 | Below threshold: 283631
# 2026-02-15 13:37:56,061 [INFO]   Progress: {'labor': 73987, 'railroad': 34990, 'both': 17207} | Excluded: 2685 | Below threshold: 286480
# 2026-02-15 13:39:26,450 [INFO]   Progress: {'labor': 73988, 'railroad': 41979, 'both': 17210} | Excluded: 2702 | Below threshold: 289335
# 2026-02-15 13:40:49,984 [INFO]   Progress: {'labor': 73988, 'railroad': 48964, 'both': 17213} | Excluded: 2724 | Below threshold: 292180
# 2026-02-15 13:42:37,362 [INFO]   Progress: {'labor': 73988, 'railroad': 55935, 'both': 17216} | Excluded: 2743 | Below threshold: 295062
# 2026-02-15 13:44:27,480 [INFO]   Progress: {'labor': 73988, 'railroad': 62825, 'both': 17221} | Excluded: 2757 | Below threshold: 298047
# 2026-02-15 13:46:13,124 [INFO]   Progress: {'labor': 73988, 'railroad': 69677, 'both': 17223} | Excluded: 2786 | Below threshold: 300965
# 2026-02-15 13:47:49,176 [INFO]   Progress: {'labor': 73988, 'railroad': 76510, 'both': 17223} | Excluded: 2805 | Below threshold: 303916
# 2026-02-15 13:49:15,758 [INFO]   Progress: {'labor': 73988, 'railroad': 83387, 'both': 17228} | Excluded: 2836 | Below threshold: 306785
# 2026-02-15 13:50:53,537 [INFO]   Progress: {'labor': 73988, 'railroad': 90248, 'both': 17235} | Excluded: 2858 | Below threshold: 309711
# 2026-02-15 13:52:32,069 [INFO]   Progress: {'labor': 73988, 'railroad': 97061, 'both': 17246} | Excluded: 2882 | Below threshold: 312683
# 2026-02-15 13:54:10,230 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17254} | Excluded: 2902 | Below threshold: 315675
# 2026-02-15 13:55:53,519 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17264} | Excluded: 2924 | Below threshold: 318745
# 2026-02-15 13:57:41,856 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17270} | Excluded: 2943 | Below threshold: 321885
# 2026-02-15 13:59:29,784 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17280} | Excluded: 2969 | Below threshold: 325074
# 2026-02-15 14:01:13,467 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17285} | Excluded: 2986 | Below threshold: 328078
# 2026-02-15 14:02:56,240 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17287} | Excluded: 3012 | Below threshold: 330896
# 2026-02-15 14:04:40,536 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17293} | Excluded: 3037 | Below threshold: 333831
# 2026-02-15 14:06:28,198 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17296} | Excluded: 3084 | Below threshold: 336479
# 2026-02-15 14:07:48,226 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17298} | Excluded: 3112 | Below threshold: 339234
# 2026-02-15 14:08:59,230 [INFO]   Progress: {'labor': 73989, 'railroad': 100000, 'both': 17303} | Excluded: 3144 | Below threshold: 341978
# 2026-02-15 14:10:10,505 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17329} | Excluded: 3167 | Below threshold: 344918
# 2026-02-15 14:11:39,743 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17348} | Excluded: 3193 | Below threshold: 347871
# 2026-02-15 14:13:18,114 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17355} | Excluded: 3219 | Below threshold: 351008
# 2026-02-15 14:15:00,438 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17359} | Excluded: 3248 | Below threshold: 354134
# 2026-02-15 14:16:40,392 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17362} | Excluded: 3271 | Below threshold: 357384
# 2026-02-15 14:18:19,442 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17365} | Excluded: 3307 | Below threshold: 360665
# 2026-02-15 14:19:58,362 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17366} | Excluded: 3331 | Below threshold: 363845
# 2026-02-15 14:21:32,596 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17372} | Excluded: 3354 | Below threshold: 366965
# 2026-02-15 14:23:05,942 [INFO]   Progress: {'labor': 73990, 'railroad': 100000, 'both': 17380} | Excluded: 3369 | Below threshold: 370076
# 2026-02-15 14:24:38,541 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17385} | Excluded: 3395 | Below threshold: 373073
# 2026-02-15 14:26:08,498 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17389} | Excluded: 3411 | Below threshold: 376177
# 2026-02-15 14:27:35,976 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17393} | Excluded: 3434 | Below threshold: 379405
# 2026-02-15 14:29:04,733 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17400} | Excluded: 3446 | Below threshold: 382566
# 2026-02-15 14:30:11,221 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17408} | Excluded: 3470 | Below threshold: 385679
# 2026-02-15 14:31:16,168 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17413} | Excluded: 3494 | Below threshold: 388840
# 2026-02-15 14:32:23,255 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17422} | Excluded: 3517 | Below threshold: 391998
# 2026-02-15 14:33:28,903 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17428} | Excluded: 3536 | Below threshold: 395184
# 2026-02-15 14:34:33,213 [INFO]   Progress: {'labor': 73991, 'railroad': 100000, 'both': 17440} | Excluded: 3559 | Below threshold: 398318
# 2026-02-15 14:35:35,581 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17444} | Excluded: 3573 | Below threshold: 401424
# 2026-02-15 14:36:35,500 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17449} | Excluded: 3591 | Below threshold: 404692
# 2026-02-15 14:37:34,326 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17456} | Excluded: 3605 | Below threshold: 407888
# 2026-02-15 14:38:34,561 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17460} | Excluded: 3617 | Below threshold: 411031
# 2026-02-15 14:39:34,254 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17468} | Excluded: 3650 | Below threshold: 414205
# 2026-02-15 14:40:38,323 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17483} | Excluded: 3687 | Below threshold: 417430
# 2026-02-15 14:41:40,613 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17491} | Excluded: 3729 | Below threshold: 420724
# 2026-02-15 14:42:45,584 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17501} | Excluded: 3772 | Below threshold: 423966
# 2026-02-15 14:43:52,521 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17514} | Excluded: 3812 | Below threshold: 427314
# 2026-02-15 14:44:57,702 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17521} | Excluded: 3844 | Below threshold: 430509
# 2026-02-15 14:46:04,193 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17525} | Excluded: 3877 | Below threshold: 433849
# 2026-02-15 14:47:09,051 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17536} | Excluded: 3903 | Below threshold: 437104
# 2026-02-15 14:48:15,430 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17542} | Excluded: 3929 | Below threshold: 440311
# 2026-02-15 14:49:24,364 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17549} | Excluded: 3954 | Below threshold: 443388
# 2026-02-15 14:51:14,940 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17560} | Excluded: 3980 | Below threshold: 446391
# 2026-02-15 14:53:09,532 [INFO]   Progress: {'labor': 73992, 'railroad': 100000, 'both': 17571} | Excluded: 4000 | Below threshold: 449369
# 2026-02-15 14:55:00,713 [INFO]   Progress: {'labor': 73993, 'railroad': 100000, 'both': 17583} | Excluded: 4036 | Below threshold: 452301
# 2026-02-15 14:56:49,195 [INFO]   Progress: {'labor': 73993, 'railroad': 100000, 'both': 17590} | Excluded: 4076 | Below threshold: 455218
# 2026-02-15 14:58:41,345 [INFO]   Progress: {'labor': 73993, 'railroad': 100000, 'both': 17596} | Excluded: 4100 | Below threshold: 458307
# 2026-02-15 15:00:26,372 [INFO]   Progress: {'labor': 73993, 'railroad': 100000, 'both': 17604} | Excluded: 4129 | Below threshold: 461484
# 2026-02-15 15:02:16,472 [INFO]   Progress: {'labor': 73993, 'railroad': 100000, 'both': 17609} | Excluded: 4158 | Below threshold: 464564
# 2026-02-15 15:04:06,487 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17621} | Excluded: 4193 | Below threshold: 467637
# 2026-02-15 15:05:55,441 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17632} | Excluded: 4227 | Below threshold: 470753
# 2026-02-15 15:07:46,036 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17636} | Excluded: 4249 | Below threshold: 473826
# 2026-02-15 15:09:37,400 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17655} | Excluded: 4269 | Below threshold: 477028
# 2026-02-15 15:11:18,092 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17671} | Excluded: 4290 | Below threshold: 480318
# 2026-02-15 15:13:14,590 [INFO]   Progress: {'labor': 73994, 'railroad': 100000, 'both': 17687} | Excluded: 4313 | Below threshold: 483585
# 2026-02-15 15:15:14,842 [INFO]   Progress: {'labor': 73995, 'railroad': 100000, 'both': 17691} | Excluded: 4335 | Below threshold: 486897
# 2026-02-15 15:17:16,906 [INFO]   Progress: {'labor': 73995, 'railroad': 100000, 'both': 17716} | Excluded: 4362 | Below threshold: 490205
# 2026-02-15 15:19:17,399 [INFO]   Progress: {'labor': 73996, 'railroad': 100000, 'both': 17729} | Excluded: 4388 | Below threshold: 493462
# 2026-02-15 15:21:14,176 [INFO]   Progress: {'labor': 73996, 'railroad': 100000, 'both': 17736} | Excluded: 4408 | Below threshold: 496717
# 2026-02-15 15:23:02,789 [INFO]   Progress: {'labor': 73996, 'railroad': 100000, 'both': 17755} | Excluded: 4428 | Below threshold: 500006
# 2026-02-15 15:24:01,341 [INFO]   Progress: {'labor': 73998, 'railroad': 100000, 'both': 17774} | Excluded: 4451 | Below threshold: 503220
# 2026-02-15 15:24:59,906 [INFO]   Progress: {'labor': 73998, 'railroad': 100000, 'both': 17784} | Excluded: 4466 | Below threshold: 506489
# 2026-02-15 15:25:57,409 [INFO]   Progress: {'labor': 73999, 'railroad': 100000, 'both': 17798} | Excluded: 4488 | Below threshold: 509717
# 2026-02-15 15:27:11,744 [INFO]   Progress: {'labor': 73999, 'railroad': 100000, 'both': 17806} | Excluded: 4505 | Below threshold: 513040
# 2026-02-15 15:28:26,798 [INFO]   Progress: {'labor': 73999, 'railroad': 100000, 'both': 17814} | Excluded: 4520 | Below threshold: 516471
# 2026-02-15 15:29:42,350 [INFO]   Progress: {'labor': 73999, 'railroad': 100000, 'both': 17821} | Excluded: 4538 | Below threshold: 519754
# 2026-02-15 15:31:00,537 [INFO]   Progress: {'labor': 73999, 'railroad': 100000, 'both': 17833} | Excluded: 4552 | Below threshold: 523042
# 2026-02-15 15:32:15,476 [INFO]   Progress: {'labor': 74000, 'railroad': 100000, 'both': 17847} | Excluded: 4563 | Below threshold: 526326
# 2026-02-15 15:33:30,919 [INFO]   Progress: {'labor': 74000, 'railroad': 100000, 'both': 17857} | Excluded: 4577 | Below threshold: 529667
# 2026-02-15 15:34:47,476 [INFO]   Progress: {'labor': 74000, 'railroad': 100000, 'both': 17872} | Excluded: 4595 | Below threshold: 532973
# 2026-02-15 15:35:04,264 [INFO]   Progress: {'labor': 74001, 'railroad': 100000, 'both': 17873} | Excluded: 4598 | Below threshold: 533691
# Final counts:
#   labor: 74,001
#   railroad: 100,000
#   both: 17,873
#   Excluded (Civil War/false positives): 4,598
#   Below threshold: 533,691

# %%
# Save classified articles to JSON
for category, articles in classified.items():
    filename = f"{category}_only.json" if category != 'both' else "both.json"
    output_path = OUTPUT_DIR / filename
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(articles, f, ensure_ascii=False)
    print(f"Saved {len(articles):,} articles to {output_path} ({output_path.stat().st_size / 1e6:.1f} MB)")
# Out:
# Saved 74,001 articles to data\classified_articles\labor_only.json (212.7 MB)
# Saved 100,000 articles to data\classified_articles\railroad_only.json (272.8 MB)
# Saved 17,873 articles to data\classified_articles\both.json (70.5 MB)

# %% [markdown]
# ## Verification: Sample 100 Articles per Category
#
# Manually review a random sample to check classification accuracy. Target: >85% precision.

# %%
import textwrap

# Print random samples for manual review
SAMPLE_SIZE = 10  # Increase to 100 for full verification

for category, articles in classified.items():
    print(f"\n{'='*80}")
    print(f"CATEGORY: {category.upper()} (sample of {SAMPLE_SIZE})")
    print(f"{'='*80}\n")
    
    sample = random.sample(articles, min(SAMPLE_SIZE, len(articles)))
    
    for i, article in enumerate(sample, 1):
        print(f"--- Article {i} ---")
        print(f"Year: {article['year']:<6} | ISSN: {article['issn']}")
        print(f"Labor score: {article['labor_score']:<6.2f} | Railroad score: {article['railroad_score']:.2f}")
        print(f"\nText preview:")
        
        # Wrap text to 80 characters
        wrapped_text = textwrap.fill(article['text'][:500], width=80)
        print(wrapped_text)
        
        print(f"\n{'-'*80}\n")
# Out:
# ================================================================================
# CATEGORY: LABOR (sample of 10)
# ================================================================================
#
# --- Article 1 ---
# Year: 1886   | ISSN: 2577-6754
# Labor score: 11.00  | Railroad score: 0.00
#
# Text preview:
# Powderly May Refuse to Call a Special Session OF the General Assembly. NEW YORK,
# December 27.-The Tribune to-day says: Organized labor seems to be in a bad
# tangle which grows worse in stead of better. The dissatisfaction of the Knights
# of Labor is growing more wide spread, and some members Of the order are afraid
# that the present difficulty can only result in spite. There seems to be little
# doubt that the legal requirements for call for a special session of the General
# Assembly will be fulfilled
#
# --------------------------------------------------------------------------------
#
# --- Article 2 ---
# Year: 1883   | ISSN: 2331-3285
# Labor score: 4.00   | Railroad score: 1.00
#
# Text preview:
# The other day q number Of the railroad lands at work on the Texas Trunk line
# truck for higher wages. They were re- sewing at the time the very best pay ior
# ,he services they were rendering, and 1T lie beyond the regular remuneration.
# Tie OF the company, Captain Adams, declined to yield to the demand and Issued to
# let the strikers go. Upon learning this they concluded it would be best to
# retain their positions at the pay they were getting Then why the sudden strike?
# Its known that 80 many miles O
#
# --------------------------------------------------------------------------------
#
# --- Article 3 ---
# Year: 1877   | ISSN: 2157-1260
# Labor score: 7.00   | Railroad score: 2.00
#
# Text preview:
# M III SkriK aU1ssInn atanss WAR rHE pfTrsRuRa1 sfRik ERs DEMANDED s,s pRRpIoUs
# no THE 0uTBREA 55 IfrrsssRati, July 10. "a large and very enthusiastic meeting
# Of the Train. Mems 4 Jn}of, WIS held 3at Ph1nix Hall, on Esey- enth street,
# tonight n early all the strikers were present, and The meeting was y va q
# dressed by many speakers. But one se saI.. ment was expressed, and TINT
# deterMl.nu. Han "a continue the strike. the mse .s was yery orderly. The
# strikers were loineu ~, ,ha meeting BY the engi
#
# --------------------------------------------------------------------------------
#
# --- Article 4 ---
# Year: 1888   | ISSN: 2158-9062
# Labor score: 4.00   | Railroad score: 0.00
#
# Text preview:
# Tho Democratic Party Not the Friend OF the Working Glasses, in That Section, at
# Least. Mr.. Barry has just returned from trip through the South, where he paid
# particular attention TO the industrial situation. In some sections the working-
# men, who are mostly negroes, are paid the most meager wages-so low in fact that
# the old slave holders and capitalists prefer the present situation to the slave-
# holding regime. The evolutionary effects of generations of bond age, the lack of
# education, race preju
#
# --------------------------------------------------------------------------------
#
# --- Article 5 ---
# Year: 1889   | ISSN: 2470-329X
# Labor score: 4.00   | Railroad score: 0.00
#
# Text preview:
# A Day of Rioting and Bouts Betweer the Men, the Police and the scabs. New YoRK,
# January 3O.-The street car tie up continues. This morning the strikers
# overturned wagon on the Grand street road. The police reserve was called out and
# dispersed the mob. Trouble is feared. Only few cars could be run to-day. A car
# on Sixth avenue started at 8 o'clock, guarded by three policemen. At Bleecker
# and Carmine streets they were overpowered by mob and the car over turned. Police
# headquarters have been asked t
#
# --------------------------------------------------------------------------------
#
# --- Article 6 ---
# Year: 1882   | ISSN: 2169-723X
# Labor score: 5.00   | Railroad score: 0.00
#
# Text preview:
# THE great labor strikes in the North and Northwest have about ended. The strike
# at Cleveland which begun May 8th came to an end last Saturday, July %, the
# strikers giving under and going to work at the old wages.
#
# --------------------------------------------------------------------------------
#
# --- Article 7 ---
# Year: 1885   | ISSN: 2151-3899
# Labor score: 7.00   | Railroad score: 0.00
#
# Text preview:
# GALVESTON, November 10th.--The COM mittee Of arbitration for the settlement of
# the recent strike inaugurated in this city held a continuous session to-day The
# tes- timonv taken is being reduced to writing. The situation continues grave.
# ColoTed laborers all over the city are awaiting the result of the arbitration
# committees labors with undisguised interest. They feel that their interests are
# being jeopardized by the Knights of Labor. This feeling has been intensified by
# demand from the local AS
#
# --------------------------------------------------------------------------------
#
# --- Article 8 ---
# Year: 1887   | ISSN: 2332-757X
# Labor score: 5.00   | Railroad score: 0.00
#
# Text preview:
# W N>hl\tsi)N. NOV. 1881 The chief events OF interest of the week are the
# reception OF the British committee on International comtro- ver.ies. by the
# Presilent-the purpose being to settle such matters in the calm counsels OF peace
# rather than in the stormy and sang,iinary strife OF battle and the adverse
# decision OF the United States supreme Court in the ease oi the Chicago
# Anarchists for a new trail. This result caused not the least surprise in the
# capital, rs 1t hls been Anticipated as the inev
#
# --------------------------------------------------------------------------------
#
# --- Article 9 ---
# Year: 1886   | ISSN: 2329-4019
# Labor score: 6.00   | Railroad score: 0.00
#
# Text preview:
# The color line episode, which the meet ing of the Knights of Labor developed at
# their convention IN Richmond. may yet have such q bearing on the fortunes of the
# republican and democratic parties as few members of either organization now real
# ize. The knights admit colored men to their order on terms of equality with the
# white members. While in Richmond they demanded FROM the natives full rec
# ognition of the civil aud social rights of the negro delegates. THIS incensed
# the Bourbon element of the
#
# --------------------------------------------------------------------------------
#
# --- Article 10 ---
# Year: 1877   | ISSN: 2474-3224
# Labor score: 7.00   | Railroad score: 1.00
#
# Text preview:
# stop work. but they have no right to pre- vent other workmen from laboring, and
# the public is not just now in a humor to bear trifling on this question. Mr..
# Wendell Phillips, who has for years been one of the leading supporters of
# workingmen's move ments, writes:-''No man has a right to pre- vent any other man
# from working when, where and for what wages he sees fit. No man has right to
# destroy public or private property or to derange business by sudden refusal to
# work or plot to effect such arr
#
# --------------------------------------------------------------------------------
#
#
# ================================================================================
# CATEGORY: RAILROAD (sample of 10)
# ================================================================================
#
# --- Article 1 ---
# Year: 1869   | ISSN: 2331-9968
# Labor score: 0.00   | Railroad score: 4.00
#
# Text preview:
# PHILADKLrB BIA. May -. An engine a. Burlington comfy railroad exploded vest near
# Mount Holley, New Jersey, Charles L. Platt. fireman: fatally won engineer
# Goskill, and seriously InJ1rinr ductor Sayler and Ed ward Joyce. The e. bounded
# from the track aud fell into Ran, Creek. The cars were much damaged. tSecond
# Dispatch PHlLADRLPHIA May 21.-Job. Gaskill, tn- engineer injured by the
# locomotive explosion al Mount Holiey yesterday, died last nlsht and the
# conductor, John Taylor. cannot live. The loc
#
# --------------------------------------------------------------------------------
#
# --- Article 2 ---
# Year: 1877   | ISSN: 2572-5904
# Labor score: 2.00   | Railroad score: 7.00
#
# Text preview:
# Three to five Millions of Dollars Werti / of Property Destroyed. | PIPTsBURG,
# July 22.-At one O'Clock this morning, IN the ncighborhood ofthe roundhouse, a
# terrible scene was enacted The fire bells called out the department The
# roundhouse was reported burning set on fire by the strikers, and the troops
# bombarded within Thereport paraIyzed many stout hearts. It was later learned to
# be occasioned not by the burning OF the roundhouse, but by the destruction of
# long train of oil cars. Many thous- an
#
# --------------------------------------------------------------------------------
#
# --- Article 3 ---
# Year: 1871   | ISSN: 2166-1774
# Labor score: 0.00   | Railroad score: 7.00
#
# Text preview:
# JOHN +, VANLEER, IN, Ticket Agent. No. 901 CHESNUT Street. FRANCIS FUNK, Ticket
# Agent. No. 1l6 MARKET Street. SAMUEL II. WALLACE, Ticket Agent at the Depot. The
# Pennsylvania Railroad Company win not assume any risk for Baggage, except for
# Wearing Apparel and limit their responsibility to One Hun. dred Dollars in
# value. All Baggage exceeding that amount In value will be at the risk Of the
# owner, unless taken by special contract. A. ]. OASSATr, 4S General
# Superintendent, Altoona, Pa.
#
# --------------------------------------------------------------------------------
#
# --- Article 4 ---
# Year: 1872   | ISSN:
# Labor score: 0.00   | Railroad score: 5.00
#
# Text preview:
# Portland, Me-, TO- AS soon as the news became generally known in this city, this
# A. NJ, that the city Of Boston was fast succmb- ing to the destroying element, a
# train left for that city, provided most kindly by Superin- tendent Chase of the
# =. S. & p. Railroad, carrying steamer No. !, and her company, but on reaching
# Portsmouth, word was tele- graphed from Boston that their services were not
# needed, and they returned home by 9, A. NJ. Mayor kingsbury proceeded to the p.
# S. & p. Depot, and offer
#
# --------------------------------------------------------------------------------
#
# --- Article 5 ---
# Year: 1872   | ISSN: 2333-8547
# Labor score: 0.00   | Railroad score: 5.00
#
# Text preview:
# hlon....s,.I..!,....ts. 4bB Centre :.......'..' .....' Sd 3 MeDstcr
# ..,..........,... 3Y1 ~ hltcnle. ,.:.,.,..,....,,.. III 80 IfladelPhia.
# ....".",!.. IS 1T kichland.. :.............. Is So West Liberty............ Is
# 1877 '" ass 4Oi On motion the report was received and filed. II. c. Cots, who
# had been elected Justice Of Washington township but fail. ed 10 qualify in the
# prescribed time, was appointed to the office by the Board and MIR. @. having
# presented his bond, In due form aud properly st
#
# --------------------------------------------------------------------------------
#
# --- Article 6 ---
# Year: 1872   | ISSN: 2163-7229
# Labor score: 0.00   | Railroad score: 4.00
#
# Text preview:
# FATAL RAILROAD ACCIDENT A sad accident occurred just over the river last night,
# about half-past nine o'clock, on the Richmond and Danvile railroad, by which Bob
# Trice, an aged and worthy colored man, long an employee of the company, and
# experienced in the business committed to him, was instantly killed. The switch
# locomotive was engaged in moving num- Der of loaded freight cars to this side of
# the river to make up a train, the freight cars being in front coming this way.
# Just be- fore the foremo
#
# --------------------------------------------------------------------------------
#
# --- Article 7 ---
# Year: 1872   | ISSN: 2642-5416
# Labor score: 0.00   | Railroad score: 4.00
#
# Text preview:
# Maine has spoken. Her voice in favor of Grant and Wilson will re-echo from Maine
# to California, from Indiana to the Gulf States, and the cause Of Greeley will
# have been decided in the negative long before a vote has been cast for the
# electoral ticket Of the Presidency. The strongest men of the opposition were in
# the field and the most herculaneum ef- forts were made on their behalf in Maine
# and yet the army of the Republican party remains intact with a large accession
# to the majority which had d
#
# --------------------------------------------------------------------------------
#
# --- Article 8 ---
# Year: 1872   | ISSN: 2576-5604
# Labor score: 0.00   | Railroad score: 5.00
#
# Text preview:
# The bridge of the Union Pacific Railroad between Omaha and Council Bluffs was
# crossed on the 22d inst. for the first time, With loaded train.
#
# --------------------------------------------------------------------------------
#
# --- Article 9 ---
# Year: 1879   | ISSN: 2372-1170
# Labor score: 0.00   | Railroad score: 4.00
#
# Text preview:
# appellant. Appeal from the Fifth District Court, parish Of Orleans ....., anee
# of account currents OF sales to the planter for whom they were made, cannot be
# held as acting In a fiduciary character within | the intendment OF section 33 OF
# the bankrupt | laws OF the United States, and debts SO due by him are covered by
# his discharge In bank | ruptcy Justices Spencer and White dissented. BY JUSTICE
# DE BLANC. No. TAG. State OF Louisiana VS.. Thomas Pickett, appellant Appeal from
# the Supe- | rior Cr
#
# --------------------------------------------------------------------------------
#
# --- Article 10 ---
# Year: 1877   | ISSN: 2331-3285
# Labor score: 2.00   | Railroad score: 5.00
#
# Text preview:
# The Douglas Monument assoeialisn met IN Chicago ON saturday and re-. eelyed bids
# for the erection of various portions Of the monument The con, tract for the
# marble shaft was awarded 70 the llinslale'poyle company at $l5,, y The election
# contest at Lexington, Kentucky which oe'us next Monday, Is SAID To be the most
# hotly contested election which that section fas had n years. Mr. Iauton, tho
# radical nom.. nee, for the legislature, Is the strongest candidate that party
# could have chosen. Oensuring
#
# --------------------------------------------------------------------------------
#
#
# ================================================================================
# CATEGORY: BOTH (sample of 10)
# ================================================================================
#
# --- Article 1 ---
# Year: 1885   | ISSN: 2331-3285
# Labor score: 3.00   | Railroad score: 3.00
#
# Text preview:
# -S>""S Ao AeNuiuess Tor the Grand Picnic and Parade-Real Estate Transfer-Cstton
# Receipts, Per- sonal and Other News. DHNIsoN, Oct. 2-lSpeeial.l-Every- thing is
# in readiness for the grand picnic and parade, under the aus piees OF the Knights
# of Labor, which takes place tomorrow. A large crowd OF Whiting members of tho
# ordsr, az well az outside parties, are expected, EN-. inent speakers Will be
# present aud a general good time is expected. Rohrbaugh, Moore q Co., proprie.
# tors or THO Denison BankS
#
# --------------------------------------------------------------------------------
#
# --- Article 2 ---
# Year: 1886   | ISSN:
# Labor score: 4.00   | Railroad score: 3.00
#
# Text preview:
# GEORGIA GLEANINGS. Charly Rose has escaped from Dade Coal Mines. Over $4,000
# chickens are sold an nually in GAINESVILLE. Luther Ellison has been sentenced to
# life Imprisonment for killing Bart Wall in Atlanta. Ed. Sutton. negro brakeman,
# was killed at Montezuma last Friday night while coupling freight train. A negro
# woman stole some dresses in Columbus and used one of them as her baptismal robe.
# Every indication points to sue cessful business season, but the boom will not
# get under Roadway until
#
# --------------------------------------------------------------------------------
#
# --- Article 3 ---
# Year: 1890   | ISSN: 2329-2385
# Labor score: 4.00   | Railroad score: 4.00
#
# Text preview:
# ADVICEs from Hiogo. Japan, state & NJ the mail steamer Musaschi Maru has been
# lost of Cochin and that all of her crew with the exception of one Japanese were
# drowned JOHN d. RocKEFELLER has given 81. 600 600 more to the new Baptist Uni
# versity at Chicago His previous gift was $500, 900. THE two victims of the
# cyclone near Manning, Iowa, were William Ferry and his child Several were
# injured, but not fatally. THE boiler of a threshing machine ex- ploded at
# MarshfelL O., killing two men IT is repor
#
# --------------------------------------------------------------------------------
#
# --- Article 4 ---
# Year: 1888   | ISSN: 1941-0646
# Labor score: 3.00   | Railroad score: 4.00
#
# Text preview:
# THE PLACES OF 1000 STRIKERS AT PHILADELPHIA FILLED BY NEW MEN. PHILADELPHIA,
# Jan. ,Spectab.-There was tho greatest anxiety to-day at the Fourhst Office OF
# the beading railroad Company over the situation caused Inv the determination Of
# tho miners in the 6chuylkll region to ioIn I'm the strike to-day. The number Of
# Knight, OF Labor OF tho local Assemblies now out OF | the strike In this city IS
# estimated at about 1000 Tho employees at Third and Berks SITS. comprising |
# Assembly No. $50 refused to
#
# --------------------------------------------------------------------------------
#
# --- Article 5 ---
# Year: 1888   | ISSN: 2331-9968
# Labor score: 6.00   | Railroad score: 6.00
#
# Text preview:
# FeaSs that the BrOsherh0Od WAn TIE Up An the Roads I'm the West In Or. der 10
# Wtn-Easserm MEN saSA % - Returning Home. CHICAGO. March 2.-Referring 70 the
# summoning here OF the grievance committees OF the various railroads by Chief
# Arthur and Sargent the Tones says: opinion In railroad circles Is divided a. 20
# the probability OF the strike being extended be- yond the Burlington. Those who
# take the view that it Will be confined within ITS present bounds hood could nos
# co%t sSea 81 se ss a folly as
#
# --------------------------------------------------------------------------------
#
# --- Article 6 ---
# Year: 1888   | ISSN: 1941-3033
# Labor score: 7.00   | Railroad score: 4.00
#
# Text preview:
# WASHINGTON, February 1.-THE special committee of the House to IN yestigate the
# Reading strikes got to work this morning john L. Lee, OF Philadelphia, a
# sympathiZer with the railroad str kers, was the first witness. Lee said he did
# not consider that there was any strike Oh the Reading load; 1t was a lockout.
# Five crews, he said, re- fused to move cars at Port Richmond and genera!
# Superintendent SWeigart discharged them without giving them hearing. There was
# an agreement that no men should be disc
#
# --------------------------------------------------------------------------------
#
# --- Article 7 ---
# Year: 1874   | ISSN:
# Labor score: 3.00   | Railroad score: 3.00
#
# Text preview:
# The Erie railway passenger agent has issu ed instructions to all ticket agents
# not to sell tickets to any point west of Susquehanna, till further orders, as
# passengers cannot be for warded beyond that place. The farmers and villagers in
# the neighborhood of Hornells- vile sympathize with the strikers. The prob
# ability is that the strike will soon become general. A despatch from Port Jervis
# says an at tempt was made to extend the strike of the brakemen to the Delaware
# division of the Erie Railroad
#
# --------------------------------------------------------------------------------
#
# --- Article 8 ---
# Year: 1886   | ISSN: 2331-7817
# Labor score: 4.00   | Railroad score: 5.00
#
# Text preview:
# Painters and paper h myers at Haverhll, Mass, numbering $50, have struck for do
# crease of working hours They demand tho same pay, S225 per day for nine hours
# work. Josephine Chauquette has been probably fatally burned at Fall River, Mass,
# by the explosion of Il kerosene lamp. The railroad commissioners have reported
# favorably upon the petition of the Chat ham, Mass, Railroad Company for charter
# Mrs. C. Hamlin of Nashua, n. H., has committed suicide by drowning in Sandy
# pond. The Bath, Ne, Board
#
# --------------------------------------------------------------------------------
#
# --- Article 9 ---
# Year: 1889   | ISSN: 2157-1295
# Labor score: 4.00   | Railroad score: 3.00
#
# Text preview:
# MT Railroad Crossiugs-Chief BigelOw Heard Them AnabIy-Other City Hnll News.
# CHIEF BIGELow was waited upon yesterday afternoon by Councilmen Donley. Matthews
# and Evans, of the Southside, and Daniel Nor gan. chairman Of the committee
# appointed at the Indignation meeting on the Southside the other night, the
# object of the conference being to secure the Chiefs aid in suppressing the
# danger at the Pittsburg, Virginia and Charles ton Railroad crossings at the
# cross streets from South Twenty-ffth to So
#
# --------------------------------------------------------------------------------
#
# --- Article 10 ---
# Year: 1886   | ISSN: 2332-0974
# Labor score: 9.00   | Railroad score: 6.00
#
# Text preview:
# The scheme of Arbitration He Proposed Powderly's Denunciation of ID. A. 1O1. NEW
# YORK, April 1.-The Tribune will to- morrow publish an interview with Jay Gould
# in regard to the strike in the Southwest. In re- gard to the warnings sent out
# to the travelling public by the Knights of Labor saying that the present
# employees of the Missouri Pacific are not competent mechanics. Mr. Gould said
# that the charge was without foundation; that the road was in superior condition.
# laid with steel rails and bal
#
# --------------------------------------------------------------------------------

# %%
# Summary statistics
import pandas as pd

all_articles = []
for articles in classified.values():
    all_articles.extend(articles)

df = pd.DataFrame(all_articles)

print("\n=== Classification Summary ===")
print(f"\nCategory distribution:")
print(df['category'].value_counts())

print(f"\nYear distribution (top 10):")
print(df['year'].value_counts().head(10))

print(f"\nScore statistics by category:")
print(df.groupby('category')[['labor_score', 'railroad_score']].describe().round(1))
# Out:
# === Classification Summary ===
#
# Category distribution:
# category
# railroad    100000
# labor        74001
# both         17873
# Name: count, dtype: int64
#
# Year distribution (top 10):
# year
# 1872    22697
# 1871    22044
# 1886    21115
# 1869    20088
# 1870    19981
# 1873    16785
# 1888    11163
# 1887    10991
# 1890     9580
# 1889     6549
# Name: count, dtype: int64
#
# Score statistics by category:
#          labor_score                                     railroad_score       \
#                count mean  std  min  25%  50%  75%   max          count mean
# category
# both         17873.0  4.4  1.9  3.0  3.0  4.0  5.0  22.0        17873.0  4.7
# labor        74001.0  5.3  1.7  4.0  4.0  5.0  6.0  24.0        74001.0  0.3
# railroad    100000.0  0.1  0.4  0.0  0.0  0.0  0.0   2.0       100000.0  4.9
#
#
#           std  min  25%  50%  75%   max
# category
# both      1.8  3.0  4.0  4.0  5.0  19.0
# labor     0.6  0.0  0.0  0.0  0.0   2.0
# railroad  1.5  4.0  4.0  4.0  5.0  19.0
